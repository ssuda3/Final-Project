# %% [markdown]
# # Final Project - Wine Quality Prediction

# %%
# %matplotlib inline
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
import matplotlib.pyplot as plt

# %% [markdown]
# ##White Wine

# %% [markdown]
# ###Exploratory Data Analysis

# %%
df = pd.read_csv('winequality-white.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
#Renaming column names
df.rename(columns={'fixed acidity':'fixed_acidity'}, inplace=True)

# %%
df.rename(columns={'volatile acidity':'volatile_acidity'}, inplace=True)

# %%
df.rename(columns={'citric acid':'citric_acid'}, inplace=True)

# %%
df.rename(columns={'residual sugar':'residual_sugar'}, inplace=True)

# %%
df.rename(columns={'free sulfur dioxide':'free_sulfur_dioxide'}, inplace=True)

# %%
df.rename(columns={'total sulfur dioxide':'total_sulfur_dioxide'}, inplace=True)

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %% [markdown]
# #####Let us find out if the variables are categorical or continuous

# %%
df.fixed_acidity.value_counts()
# Out:
# 6.8    308
# 6.6    290
# 6.4    280
# 6.9    241
# 6.7    236
# 7.0    232
# 6.5    225
# 7.2    206
# 7.1    200
# 7.4    194
# 6.2    192
# 6.3    188
# 6.0    184
# 7.3    178
# 6.1    155
# ...
# 10.30    2
# 4.20     2
# 9.90     2
# 6.15     2
# 9.50     2
# 7.15     2
# 10.70    2
# 14.20    1
# 4.50     1
# 10.20    1
# 11.80    1
# 3.80     1
# 4.60     1
# 6.45     1
# 3.90     1
# Length: 68, dtype: int64

# %%
df.volatile_acidity.value_counts()
# Out:
# 0.28    263
# 0.24    253
# 0.26    240
# 0.25    231
# 0.22    229
# 0.27    218
# 0.23    216
# 0.20    214
# 0.30    198
# 0.21    191
# 0.32    182
# 0.18    177
# 0.19    170
# 0.29    160
# 0.31    148
# ...
# 0.085    1
# 0.545    1
# 0.730    1
# 0.930    1
# 0.910    1
# 0.965    1
# 0.215    1
# 0.785    1
# 0.740    1
# 0.685    1
# 0.175    1
# 0.710    1
# 0.815    1
# 1.005    1
# 0.905    1
# Length: 125, dtype: int64

# %%
df.citric_acid.value_counts()
# Out:
# 0.30    307
# 0.28    282
# 0.32    257
# 0.34    225
# 0.29    223
# 0.26    219
# 0.27    216
# 0.49    215
# 0.31    200
# 0.33    183
# 0.24    181
# 0.36    177
# 0.35    137
# 0.25    136
# 0.37    134
# ...
# 0.63    4
# 0.70    3
# 0.80    2
# 0.82    2
# 0.03    2
# 0.78    2
# 0.91    2
# 0.81    2
# 0.79    2
# 1.23    1
# 0.99    1
# 0.11    1
# 0.86    1
# 0.88    1
# 1.66    1
# Length: 87, dtype: int64

# %%
df.residual_sugar.value_counts()
# Out:
# 1.2    187
# 1.4    184
# 1.6    165
# 1.3    147
# 1.1    146
# 1.5    142
# 1.7     99
# 1.8     99
# 1.0     93
# 2.0     79
# 1.9     59
# 2.2     56
# 2.1     51
# 5.0     43
# 2.3     42
# ...
# 19.60    1
# 1.75     1
# 15.15    1
# 19.35    1
# 6.95     1
# 16.45    1
# 3.15     1
# 14.05    1
# 20.15    1
# 8.45     1
# 8.55     1
# 19.90    1
# 2.65     1
# 17.00    1
# 20.30    1
# Length: 310, dtype: int64

# %%
df.chlorides.value_counts()
# Out:
# 0.044    201
# 0.036    200
# 0.042    184
# 0.040    182
# 0.046    181
# 0.048    174
# 0.047    171
# 0.045    170
# 0.050    170
# 0.034    168
# 0.038    167
# 0.037    160
# 0.039    157
# 0.041    147
# 0.043    141
# ...
# 0.102    1
# 0.112    1
# 0.145    1
# 0.290    1
# 0.239    1
# 0.091    1
# 0.120    1
# 0.179    1
# 0.105    1
# 0.115    1
# 0.077    1
# 0.204    1
# 0.009    1
# 0.200    1
# 0.301    1
# Length: 160, dtype: int64

# %%
df.free_sulfur_dioxide.value_counts()
# Out:
# 29    160
# 31    132
# 35    129
# 26    129
# 34    128
# 36    127
# 24    118
# 28    112
# 33    112
# 25    111
# 37    111
# 23    110
# 32    109
# 41    104
# 40    103
# ...
# 15.5     1
# 88.0     1
# 77.5     1
# 118.5    1
# 146.5    1
# 42.5     1
# 40.5     1
# 39.5     1
# 19.5     1
# 30.5     1
# 138.5    1
# 61.5     1
# 51.5     1
# 70.5     1
# 23.5     1
# Length: 132, dtype: int64

# %%
df.total_sulfur_dioxide.value_counts()
# Out:
# 111    69
# 113    61
# 117    57
# 118    55
# 128    54
# 114    54
# 150    54
# 122    54
# 124    53
# 140    52
# 126    50
# 133    50
# 98     49
# 125    49
# 149    48
# ...
# 303.0    1
# 9.0      1
# 294.0    1
# 282.0    1
# 260.0    1
# 255.0    1
# 26.0     1
# 246.0    1
# 232.0    1
# 344.0    1
# 48.0     1
# 44.0     1
# 33.0     1
# 31.0     1
# 238.5    1
# Length: 251, dtype: int64

# %%
df.density.value_counts()
# Out:
# 0.9920    64
# 0.9928    61
# 0.9932    53
# 0.9930    52
# 0.9934    50
# 0.9938    49
# 0.9927    47
# 0.9944    46
# 0.9948    45
# 0.9924    44
# 0.9954    44
# 0.9986    42
# 0.9956    41
# 0.9958    40
# 0.9918    40
# ...
# 0.99171    1
# 0.99841    1
# 0.99698    1
# 0.99734    1
# 0.99751    1
# 0.98997    1
# 0.99453    1
# 0.99009    1
# 0.98995    1
# 0.99554    1
# 0.98779    1
# 0.99436    1
# 0.99267    1
# 1.00241    1
# 0.99407    1
# Length: 890, dtype: int64

# %%
df.pH.value_counts()
# Out:
# 3.14    172
# 3.16    164
# 3.22    146
# 3.19    145
# 3.18    138
# 3.20    137
# 3.08    136
# 3.15    136
# 3.10    135
# 3.12    134
# 3.24    132
# 3.11    126
# 3.17    124
# 3.13    117
# 3.23    116
# ...
# 3.80    2
# 3.75    2
# 3.69    2
# 3.68    2
# 3.82    1
# 3.70    1
# 3.62    1
# 2.74    1
# 3.79    1
# 3.67    1
# 2.72    1
# 2.77    1
# 3.81    1
# 2.84    1
# 2.82    1
# Length: 103, dtype: int64

# %%
df.sulphates.value_counts()
# Out:
# 0.50    249
# 0.46    225
# 0.44    216
# 0.38    214
# 0.42    181
# 0.48    179
# 0.45    178
# 0.47    172
# 0.40    168
# 0.54    167
# 0.49    166
# 0.43    161
# 0.52    156
# 0.39    151
# 0.51    140
# ...
# 0.96    3
# 0.83    2
# 0.86    2
# 0.94    2
# 0.92    2
# 0.87    2
# 1.06    1
# 1.01    1
# 1.08    1
# 0.97    1
# 0.22    1
# 0.23    1
# 1.00    1
# 0.99    1
# 0.89    1
# Length: 79, dtype: int64

# %%
df.alcohol.value_counts()
# Out:
# 9.4     229
# 9.5     228
# 9.2     199
# 9.0     185
# 10.0    162
# 10.5    160
# 11.0    158
# 10.4    153
# 9.1     144
# 9.8     136
# 10.8    135
# 9.3     134
# 10.2    130
# 9.6     128
# 11.4    121
# ...
# 13.133333    1
# 11.550000    1
# 10.650000    1
# 10.566667    1
# 12.066667    1
# 11.850000    1
# 11.733333    1
# 13.550000    1
# 10.980000    1
# 14.200000    1
# 10.033333    1
# 11.066667    1
# 11.266667    1
# 11.950000    1
# 12.333333    1
# Length: 103, dtype: int64

# %%
df.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# dtype: int64

# %% [markdown]
# ####From the above findings, we note that the dataset has no categorical variables.

# %%
#Let us find out if there are any 'Null' or Missing values
df.isnull()
# Out:
#      fixed_acidity volatile_acidity citric_acid residual_sugar chlorides  \
# 0            False            False       False          False     False
# 1            False            False       False          False     False
# 2            False            False       False          False     False
# 3            False            False       False          False     False
# 4            False            False       False          False     False
# 5            False            False       False          False     False
# 6            False            False       False          False     False
# 7            False            False       False          False     False
# 8            False            False       False          False     False
# 9            False            False       False          False     False
# 10           False            False       False          False     False
# 11           False            False       False          False     False
# ...

# %% [markdown]
# ####There are no missing or "Null" values in the dataset. No handling of missing values required.

# %%
df.shape
# Out:
# (4898, 12)

# %% [markdown]
# #Dataset Description - White wine
#
# ####Source of dataset - https://archive.ics.uci.edu/ml/datasets/Wine+Quality
#
# ####No. of instances - 4898 rows and 12 columns
#
# ####Attributes of the dataset - Fixed Acidity, volatile acidity, citric acid, residual sugar, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality
#
# ####Missing values - None

# %% [markdown]
# ###Model

# %%
df = pd.read_csv('winequality-white.csv', header=0)
#For our binary classification as the scale is 1-10 we want to make a new column so that anything above 5 is considered "good"
df['good'] = (df.quality > 5).astype(int)

# %%
#Use the describe function to see the variables and get some basic statistics. 

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df.groupby('good').mean()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# good
# 0          6.961524          0.310265     0.334311        7.054451   0.051436
# 1          6.801059          0.262121     0.334131        6.057658   0.042921
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# good
# 0               35.338720            148.597866  0.995160  3.170457
# 1               35.292664            133.207489  0.993457  3.197231
#
#       sulphates   alcohol   quality
# good
# 0      0.481506   9.84953  4.876220
# 1      0.494045  10.84888  6.382136

# %%
#histogram of wines by the quality of the wine. As shown here the majority of the wines fall are classified 
#as a 5 or 6 on a scale of 1-10.

# %pylab inline

plt.hist(df.quality)
plt.title("Distribution of White Wine Quality")
plt.xlabel("Wine Quality")
plt.ylabel("Count of Wines")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['clf']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#As we are trying to predict to see if a wine is below or above average 'quality' 
#we are trying to see if there are any patterns for each of the variables based on means. 

df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# ...

# %%
#Looking at the different variables I have selected the following features:'volatile acidity', 'citric acid', 'chlorides', 
#'alcohol', 'pH', 'sulphates' to predict whether or not a wine is 'good'.

cols_to_keep = ['volatile acidity', 'citric acid', 'chlorides', 'alcohol', 'pH', 'sulphates']
x = df[cols_to_keep]
y = df.good.values

# %%
#Create the model using Logistic Regression, fit it, and generate a score based on the selected features. 
#Using the selected features we see a score of 73%. 

model = LogisticRegression()
model.fit(x, y)
model.score(x, y)
# Out:
# 0.73764801959983661

# %%
#Split up the data set into test and training sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)
testmodel = LogisticRegression()
testmodel.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
#Perform cross validation using 5 folds
scores = cross_val_score(LogisticRegression(), x, y, scoring='accuracy', cv=5)
print scores
print scores.mean()
# Out:
# [ 0.6877551   0.70918367  0.76632653  0.74770174  0.74259448]
# 0.730712305351

# %% [markdown]
# ######RANDOM FOREST TO FIND THE MOST IMPORTANT FEATURES THAT DETERMINE THE QUALITY OF WHITE WINE

# %%
from sklearn.ensemble import RandomForestClassifier
# An efficient data structure. 
import pandas as pd

# Import the data
X = pd.read_csv("winequality-white.csv")
y = X.pop("quality")

# %%
X.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
# Make train and test datasets
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25)

# %%
clf = RandomForestClassifier(n_estimators= 15) 
clf.fit(X,y) 
imp = clf.feature_importances_ 
names = df.columns 
imp, names = zip(*sorted(zip(imp, names))) 
plt.barh(range(len(names)), imp, align = 'center') 
plt.yticks(range(len(names)), names) 
plt.xlabel('Importance of features - white wine') 
plt.ylabel('Features') 
plt.title('Importance of each feature') 
plt.show()

# %% [markdown]
# ##Red Wine

# %% [markdown]
# ###Exploratory Data Analysis

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.rename(columns={'volatile acidity':'volatile_acidity'}, inplace=True)

# %%
df.rename(columns={'fixed acidity':'fixed_acidity'}, inplace=True)

# %%
df.rename(columns={'citric acid':'citric_acid'}, inplace=True)

# %%
df.rename(columns={'residual sugar':'residual_sugar'}, inplace=True)

# %%
df.rename(columns={'free sulfur dioxide':'free_sulfur_dioxide'}, inplace=True)

# %%
df.rename(columns={'total sulfur dioxide':'total_sulfur_dioxide'}, inplace=True)

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# #####Let us find out if the variables are categorical or continuous

# %%
df.fixed_acidity.value_counts()
# Out:
# 7.2    67
# 7.1    57
# 7.8    53
# 7.5    52
# 7.0    50
# 7.7    49
# 7.6    46
# 6.8    46
# 8.2    45
# 7.3    44
# 7.4    44
# 8.0    42
# 7.9    42
# 8.3    40
# 6.9    38
# ...
# 12.9    2
# 5.7     2
# 15.5    2
# 15.0    2
# 5.5     1
# 15.9    1
# 14.3    1
# 13.4    1
# 12.1    1
# 4.6     1
# 4.7     1
# 14.0    1
# 13.5    1
# 13.8    1
# 4.9     1
# Length: 96, dtype: int64

# %%
df.volatile_acidity.value_counts()
# Out:
# 0.60    47
# 0.50    46
# 0.43    43
# 0.59    39
# 0.36    38
# 0.58    38
# 0.40    37
# 0.38    35
# 0.49    35
# 0.39    35
# 0.56    34
# 0.41    33
# 0.52    33
# 0.54    31
# 0.46    31
# ...
# 0.890    1
# 0.975    1
# 1.070    1
# 1.090    1
# 1.185    1
# 0.595    1
# 0.565    1
# 1.580    1
# 0.950    1
# 0.845    1
# 1.025    1
# 0.865    1
# 1.115    1
# 0.805    1
# 1.240    1
# Length: 143, dtype: int64

# %%
df.citric_acid.value_counts()
# Out:
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
# 0.10     35
# 0.08     33
# 0.01     33
# 0.21     33
# 0.32     32
# 0.03     30
# 0.31     30
# 0.09     30
# 0.30     30
# 0.04     29
# ...
# 0.65    7
# 0.69    4
# 0.74    4
# 0.73    3
# 0.76    3
# 0.61    2
# 0.70    2
# 0.67    2
# 0.72    1
# 0.71    1
# 1.00    1
# 0.78    1
# 0.75    1
# 0.62    1
# 0.79    1
# Length: 80, dtype: int64

# %%
df.residual_sugar.value_counts()
# Out:
# 2.0    156
# 2.2    131
# 1.8    129
# 2.1    128
# 1.9    117
# 2.3    109
# 2.4     86
# 2.5     84
# 2.6     79
# 1.7     76
# 1.6     58
# 2.8     49
# 2.7     39
# 1.4     35
# 1.5     30
# ...
# 8.90     1
# 4.25     1
# 3.75     1
# 5.40     1
# 13.90    1
# 13.40    1
# 8.60     1
# 2.85     1
# 12.90    1
# 5.00     1
# 7.20     1
# 7.30     1
# 5.15     1
# 5.70     1
# 2.55     1
# Length: 91, dtype: int64

# %%
df.chlorides.value_counts()
# Out:
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
# 0.077    47
# 0.071    47
# 0.082    46
# 0.075    45
# 0.079    43
# 0.081    40
# 0.073    35
# 0.083    35
# 0.070    35
# 0.066    32
# ...
# 0.051    1
# 0.222    1
# 0.403    1
# 0.170    1
# 0.148    1
# 0.235    1
# 0.161    1
# 0.360    1
# 0.267    1
# 0.108    1
# 0.113    1
# 0.145    1
# 0.174    1
# 0.341    1
# 0.125    1
# Length: 153, dtype: int64

# %%
df.free_sulfur_dioxide.value_counts()
# Out:
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# 7.0      71
# 9.0      62
# 16.0     61
# 17.0     60
# 11.0     59
# 13.0     57
# 8.0      56
# 14.0     50
# 3.0      49
# 18.0     46
# 4.0      41
# 21.0     41
# 19.0     39
# 24.0     34
# 26.0     32
# 23.0     32
# 20.0     30
# 27.0     29
# 25.0     24
# 28.0     23
# 29.0     23
# 32.0     22
# 22.0     22
# 31.0     20
# 34.0     18
# 30.0     16
# 35.0     15
# 33.0     11
# 36.0     11
# 38.0      9
# 41.0      7
# 40.0      6
# 39.0      5
# 48.0      4
# 51.0      4
# 42.0      3
# 43.0      3
# 1.0       3
# 45.0      3
# 37.0      3
# 52.0      3
# 55.0      2
# 68.0      2
# 37.5      2
# 50.0      2
# 2.0       1
# 66.0      1
# 57.0      1
# 72.0      1
# 54.0      1
# 53.0      1
# 47.0      1
# 46.0      1
# 5.5       1
# 40.5      1
# Length: 60, dtype: int64

# %%
df.total_sulfur_dioxide.value_counts()
# Out:
# 28    43
# 24    36
# 15    35
# 18    35
# 23    34
# 20    33
# 14    33
# 31    32
# 38    31
# 27    30
# 19    29
# 12    29
# 13    28
# 10    27
# 17    27
# ...
# 93     2
# 155    1
# 160    1
# 152    1
# 149    1
# 153    1
# 165    1
# 142    1
# 140    1
# 139    1
# 130    1
# 126    1
# 289    1
# 116    1
# 278    1
# Length: 144, dtype: int64

# %%
df.density.value_counts()
# Out:
# 0.9972    36
# 0.9968    35
# 0.9976    35
# 0.9980    29
# 0.9962    28
# 0.9978    26
# 0.9964    25
# 0.9970    24
# 0.9994    24
# 0.9982    23
# 0.9966    23
# 0.9974    22
# 0.9984    20
# 0.9988    20
# 0.9986    19
# ...
# 0.99658    1
# 0.99479    1
# 0.99918    1
# 0.99323    1
# 0.99501    1
# 1.00012    1
# 0.99665    1
# 0.99695    1
# 0.99594    1
# 0.99901    1
# 0.99519    1
# 0.99357    1
# 0.99589    1
# 0.99935    1
# 0.99684    1
# Length: 436, dtype: int64

# %%
df.pH.value_counts()
# Out:
# 3.30    57
# 3.36    56
# 3.26    53
# 3.39    48
# 3.38    48
# 3.29    46
# 3.32    45
# 3.34    43
# 3.28    42
# 3.20    39
# 3.22    39
# 3.35    39
# 3.31    39
# 3.37    37
# 3.40    37
# ...
# 3.67    3
# 3.78    2
# 2.99    2
# 3.90    2
# 4.01    2
# 2.88    2
# 3.75    1
# 3.74    1
# 2.87    1
# 2.95    1
# 2.74    1
# 3.85    1
# 2.90    1
# 2.86    1
# 3.70    1
# Length: 89, dtype: int64

# %%
df.sulphates.value_counts()
# Out:
# 0.60    69
# 0.54    68
# 0.58    68
# 0.62    61
# 0.56    60
# 0.57    55
# 0.59    51
# 0.53    51
# 0.55    50
# 0.63    48
# 0.52    47
# 0.64    46
# 0.61    45
# 0.66    42
# 0.65    41
# ...
# 1.62    1
# 1.00    1
# 1.98    1
# 1.11    1
# 0.33    1
# 1.26    1
# 1.61    1
# 1.22    1
# 1.12    1
# 1.15    1
# 1.33    1
# 1.56    1
# 1.01    1
# 1.34    1
# 1.59    1
# Length: 96, dtype: int64

# %%
df.alcohol.value_counts()
# Out:
# 9.5     139
# 9.4     103
# 9.8      78
# 9.2      72
# 10.5     67
# 10.0     67
# 9.3      59
# 11.0     59
# 9.6      59
# 9.7      54
# 10.9     49
# 9.9      49
# 10.1     47
# 10.2     46
# 10.8     42
# ...
# 10.550000    2
# 10.033333    2
# 9.950000     1
# 13.566667    1
# 13.200000    1
# 9.050000     1
# 10.750000    1
# 9.250000     1
# 8.500000     1
# 9.566667     1
# 13.500000    1
# 11.066667    1
# 9.233333     1
# 14.900000    1
# 11.950000    1
# Length: 65, dtype: int64

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# dtype: int64

# %% [markdown]
# ####From the above findings, we note that the dataset has no categorical variables.

# %%
#Let us find out if there are any 'Null' or Missing values
df.isnull()
# Out:
#      fixed_acidity volatile_acidity citric_acid residual_sugar chlorides  \
# 0            False            False       False          False     False
# 1            False            False       False          False     False
# 2            False            False       False          False     False
# 3            False            False       False          False     False
# 4            False            False       False          False     False
# 5            False            False       False          False     False
# 6            False            False       False          False     False
# 7            False            False       False          False     False
# 8            False            False       False          False     False
# 9            False            False       False          False     False
# 10           False            False       False          False     False
# 11           False            False       False          False     False
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# ####There are no missing or "Null" values in the dataset. No handling of missing values required.

# %% [markdown]
# #Dataset Description - Red wine
#
# ####Source of dataset - https://archive.ics.uci.edu/ml/datasets/Wine+Quality
#
# ####No. of instances - 1599 rows and 12 columns
#
# ####Attributes of the dataset - Fixed Acidity, volatile acidity, citric acid, residual sugar, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality
#
# ####Missing values - None

# %% [markdown]
# ###Model

# %%
df = pd.read_csv('winequality-red.csv', header=0)
#For our binary classification as the scale is 1-10 we want to make a new column so that anything above 5 is considered "good"
df['good'] = (df.quality > 5).astype(int)

# %%
#histogram of wines by the quality of the wine. As shown here the majority of the wines fall are classified 
#as a 5 or 6 on a scale of 1-10.

# %pylab inline

plt.hist(df.quality)
plt.title("Distribution of Red Wine Quality ")
plt.xlabel("Wine Quality")
plt.ylabel("Count of Wines")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['clf']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#As we are trying to predict to see if a wine is below or above average 'quality' 
#we are trying to see if there are any patterns for each of the variables based on means. 

df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
#Looking at the different variables I have selected the following features:'volatile acidity', 'citric acid', 'chlorides', 
#'alcohol', 'pH', 'sulphates' to predict whether or not a wine is 'good'.

cols_to_keep = ['volatile acidity', 'citric acid', 'chlorides', 'alcohol', 'pH', 'sulphates']
x = df[cols_to_keep]
y = df.good.values

# %%
#Create the model using Logistic Regression, fit it, and generate a score based on the selected features. 
#Using the selected features we see a score of 73%. 

model = LogisticRegression()
model.fit(x, y)
model.score(x, y)
# Out:
# 0.73545966228893056

# %%
#Split up the data set into test and training sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)
testmodel = LogisticRegression()
testmodel.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
#Perform cross validation using 5 folds
scores = cross_val_score(LogisticRegression(), x, y, scoring='accuracy', cv=5)
print scores
print scores.mean()
# Out:
# [ 0.665625    0.709375    0.778125    0.725       0.74294671]
# 0.724214341693

# %% [markdown]
# ######RANDOM FOREST TO FIND THE MOST IMPORTANT FEATURES THAT DETERMINE THE QUALITY OF RED WINE

# %%
from sklearn.ensemble import RandomForestClassifier
# An efficient data structure. 
import pandas as pd

# Import the data
X = pd.read_csv("winequality-red.csv")
y = X.pop("quality")

# %%
X.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Make train and test datasets
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25)

# %%
clf = RandomForestClassifier(n_estimators= 15) 
clf.fit(X,y) 
imp = clf.feature_importances_ 
names = df.columns 
imp, names = zip(*sorted(zip(imp, names))) 
plt.barh(range(len(names)), imp, align = 'center') 
plt.yticks(range(len(names)), names) 
plt.xlabel('Importance of features - red wine') 
plt.ylabel('Features') 
plt.title('Importance of each feature') 
plt.show()
